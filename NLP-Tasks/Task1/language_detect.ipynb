# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\HP\Desktop\Bacancy\AI_ML\Deep_Learning\NLP\Task1\tag1.csv")
df.drop(columns="Unnamed: 0",inplace=True)

# %%
df
# Out:
#                                                content  \
# 0    "La Cour constitutionnelle,composC)e des prC)s...
# 1    "Het Grondwettelijk Hof,samengesteld uit de vo...
# 2    "Der Verfassungsgerichtshof,zusammengesetzt au...
# 3    "La Cour constitutionnelle,composC)e des prC)s...
# 4    "Het Grondwettelijk Hof,samengesteld uit de vo...
# ..                                                 ...
# 752  "Het Grondwettelijk Hof,samengesteld uit de vo...
# 753  "Het Grondwettelijk Hof,samengesteld uit de vo...
# 754  "Der Verfassungsgerichtshof,zusammengesetzt au...
# 755  "Klagen auf vC6llige oder teilweise Nichtigerk...
# 756  "Het Grondwettelijk Hof,samengesteld uit de vo...
#
#                                           keywords
# 0    Vernietigingsbevoegdheid (Grondwettelijk Hof)
# 1    Vernietigingsbevoegdheid (Grondwettelijk Hof)
# 2    Vernietigingsbevoegdheid (Grondwettelijk Hof)
# 3    Vernietigingsbevoegdheid (Grondwettelijk Hof)
# ...

# %%
from langdetect import detect

df["language"] = df["content"].apply(detect)

# %%
df
# Out:
#                                                content  \
# 0    "La Cour constitutionnelle,composC)e des prC)s...
# 1    "Het Grondwettelijk Hof,samengesteld uit de vo...
# 2    "Der Verfassungsgerichtshof,zusammengesetzt au...
# 3    "La Cour constitutionnelle,composC)e des prC)s...
# 4    "Het Grondwettelijk Hof,samengesteld uit de vo...
# ..                                                 ...
# 752  "Het Grondwettelijk Hof,samengesteld uit de vo...
# 753  "Het Grondwettelijk Hof,samengesteld uit de vo...
# 754  "Der Verfassungsgerichtshof,zusammengesetzt au...
# 755  "Klagen auf vC6llige oder teilweise Nichtigerk...
# 756  "Het Grondwettelijk Hof,samengesteld uit de vo...
#
#                                           keywords language
# 0    Vernietigingsbevoegdheid (Grondwettelijk Hof)       fr
# 1    Vernietigingsbevoegdheid (Grondwettelijk Hof)       nl
# 2    Vernietigingsbevoegdheid (Grondwettelijk Hof)       de
# 3    Vernietigingsbevoegdheid (Grondwettelijk Hof)       fr
# ...

# %%
df["language"].value_counts()
# Out:
# language
# nl    309
# fr    235
# de    212
# bn      1
# Name: count, dtype: int64

# %%
import langid

df["language_langid"] = df["content"].apply(lambda x: langid.classify(x)[0])

# %%
df["language_langid"].value_counts()
# Out:
# language_langid
# nl    310
# fr    232
# de    214
# zh      1
# Name: count, dtype: int64

# %%
# import spacy
# from spacy_langdetect import LanguageDetector

# nlp = spacy.load("en_core_web_sm")
# nlp.add_pipe("language_detector", last=True)

# def detect_lang(text):
#     doc = nlp(text)
#     return doc._.language["language"]

# df["language_spacy"] = df["content"].apply(detect_lang)

# %%
# from lingua import Language, LanguageDetectorBuilder
# detector = LanguageDetectorBuilder.from_all_languages().build()

from lingua import Language, LanguageDetectorBuilder
detector = LanguageDetectorBuilder.from_languages(
    Language.FRENCH, Language.DUTCH, Language.GERMAN
).build()

# %%
df["lang_lingua1"] = df["content"].apply(
    lambda text: (
        detector.detect_language_of(text).iso_code_639_1.name
        if isinstance(text, str)
        else None
    )
)

# %%
df[df["lang_lingua"]=="YO"]["content"]
# Out:
# 83    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# Name: content, dtype: str

# %%
df["lang_lingua"].value_counts()
# Out:
# lang_lingua
# NL    308
# FR    228
# DE    220
# YO      1
# Name: count, dtype: int64

# %%
df["lang_lingua1"].value_counts()
# Out:
# lang_lingua1
# NL    308
# FR    228
# DE    221
# Name: count, dtype: int64
