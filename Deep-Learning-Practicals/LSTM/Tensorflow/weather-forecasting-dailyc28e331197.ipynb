# %% [markdown]
# # 1 FEATURE , PAST 10 YEAR , NEXT DAY PREDICTION WINDO SIZE=6

# %%
# !pip install meteostat
# Out:
# Collecting meteostat
#   Downloading meteostat-1.6.8-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.11/dist-packages (from meteostat) (2.2.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from meteostat) (2025.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from meteostat) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1->meteostat) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1->meteostat) (2025.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->meteostat) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->meteostat) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->meteostat) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->meteostat) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->meteostat) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->meteostat) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1->meteostat) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->meteostat) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->meteostat) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->meteostat) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->meteostat) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->meteostat) (2024.2.0)
# Downloading meteostat-1.6.8-py3-none-any.whl (31 kB)
# Installing collected packages: meteostat
# Successfully installed meteostat-1.6.8

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from keras.layers import Dense,LSTM,Dropout,Flatten,BatchNormalization
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
# Out:
# 2025-05-11 13:16:02.393244: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746969362.606536      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746969362.668041      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="jainam")

# Example city
city = "Ahmedabad, India"

location = geolocator.geocode(city)

if location:
    print(f"City: {city}")
    print(f"Latitude: {location.latitude}, Longitude: {location.longitude}")
else:
    print(f"Could not find coordinates for {city}")

# %%
from meteostat import Point, Daily
import datetime


location = Point( 23.0215374, 72.5800568)
start = datetime.datetime(2014, 6, 1)
end = datetime.datetime(2024, 6, 1)

# Get historical data
data = Daily(location, start, end)
data = data.fetch()

print(data)

# %%
temperature_avg=data[["tavg"]]

# %%
print("TOTAL NULL VALUES IN DATASET:",temperature_avg.isnull().sum())

# %%
temperature_avg.dropna(inplace=True)

# %%
temperature_avg.describe()

# %%
temperature_avg.info()

# %%
temperature_avg_seq=temperature_avg.values
print(temperature_avg_seq,temperature_avg_seq.shape)

# %%
len(temperature_avg_seq)

# %%
def plot_loss_curves(history):
    """
    Plots the loss curves of a model
    """
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    accuracy = history.history['mae']
    val_accuracy = history.history['val_mae']

    epochs = range(len(history.history['loss']))


    plt.plot(epochs, loss, label='training_loss')
    plt.plot(epochs, val_loss, label='val_loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.legend()

    plt.figure()
    plt.plot(epochs, accuracy, label='training_accuracy')
    plt.plot(epochs, val_accuracy, label='val_accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.legend();

# %%
window_size=6
X=[]
Y=[]
for i in range(len(temperature_avg_seq)-window_size):
  X.append(temperature_avg_seq[i:i+window_size])
  Y.append(temperature_avg_seq[i+window_size])

# %%
X=np.array(X)
Y=np.array(Y)

# %%
print("X Shape",X.shape)
print("Y Shape",Y.shape)

# %%
X_scaler=MinMaxScaler()
Y_scaler=MinMaxScaler()

X_flat = np.array(X).reshape(-1, 1)
Y_flat = np.array(Y).reshape(-1, 1)

X_scaled=X_scaler.fit_transform(X_flat).reshape(len(X),6,1)
Y_scaled=Y_scaler.fit_transform(Y_flat).reshape(len(Y),1)

# %%
print("X_scaled Shape",X_scaled.shape)
print("Y_scaled Shape",Y_scaled.shape)

# %%
naive_model=Sequential()
naive_model.add(LSTM(128,return_sequences=True,input_shape=(window_size,1)))
naive_model.add(Dropout(0.2))
naive_model.add(LSTM(64,return_sequences=True))
naive_model.add(Dropout(0.2))
naive_model.add(LSTM(32))
naive_model.add(Dropout(0.2))
naive_model.add(Dense(1))

# %%
naive_model.summary()

# %%
naive_model.compile(optimizer="adam",loss="mse",metrics=["mae"])

# %%
history=naive_model.fit(np.array(X_scaled).reshape(-1,window_size,1),Y_scaled,epochs=100,batch_size=16,validation_split=0.2)

# %%
plot_loss_curves(history)

# %%
from meteostat import Point, Daily
import datetime


location = Point( 23.0215374, 72.5800568)
start = datetime.datetime(2024, 6, 1)
end = datetime.datetime(2024, 12, 1)

# Get historical data
data = Daily(location, start, end)
data = data.fetch()

print(data)

# %%
print(data.shape)

# %%
next_6_months_temp=data["tavg"]

# %%
plt.plot(next_6_months_temp.values.flatten())

# %%
location = Point( 23.0215374, 72.5800568)
start = datetime.datetime(2024, 5, 26)
end = datetime.datetime(2024, 5, 31)

# Get historical data
data_for_model = Daily(location, start, end)
data_for_model = data_for_model.fetch()

print(data_for_model)

# %%
data_for_model["tavg"].values

# %%
data_for_model=X_scaler.transform(np.array(data_for_model["tavg"].values).reshape(-1,1))

# %%
data_for_model=data_for_model.reshape(1,6,1)

# %%
copied=data_for_model.copy()
copied=copied[1:]
copied = np.append(copied, 1.2)
copied

# %%
data_for_model=data_for_model.flatten()

# %%
data_for_model

# %%
output=[]
for i in range(184):
    print(data_for_model)

    prediction = naive_model.predict(np.array(data_for_model).reshape(-1, window_size, 1))
    prediction_original = Y_scaler.inverse_transform(prediction.reshape(1, -1))
    output.append(prediction_original[0, 0])
    data_for_model = np.append(data_for_model[1:], prediction)

# %%
next_6_months_temp=list(next_6_months_temp.values)

# %%
print("Len Output:",len(output))
print("Len next_6_months_temp:",len(next_6_months_temp))

# %%
# Plot the two arrays
import matplotlib.pyplot as plt

plt.plot(list(next_6_months_temp), label="Actual Temperature")
plt.plot(list(output), label="Predicted Temperature")
plt.legend()
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Actual vs Predicted Temperature")
plt.show()

# %%
from sklearn.metrics import r2_score
r2_score(list(next_6_months_temp),output)

# %%
naive_model.save("naive_model.h5")

# %% [markdown]
# # 1 FEATURE , PAST 27 YEAR , NEXT DAY PREDICTION WINDO SIZE=100

# %%
"""
JUST CHANGE data[feature] : feature with tmin,tmax,tavg 
                            and change Scaler with Standard Scaler and MinMax Scaler
                            remain all other code same 

And You wil get result as i got which i mentioned in All model evalution portion.

"""

# %%
from meteostat import Point, Daily
import datetime


location = Point( 23.0215374, 72.5800568)
start = datetime.datetime(1990, 6, 1)
end = datetime.datetime(2024, 6, 1)

# Get historical data
data = Daily(location, start, end)
data = data.fetch()

print(data)

# %%
temperature_avg=data["tmin"]

# %%
print("TOTAL NULL VALUES IN DATASET:",temperature_avg.isnull().sum())

# %%
temperature_avg.dropna(inplace=True)

# %%
temperature_avg.describe()

# %%
temperature_avg.info()

# %%
temperature_avg_seq=temperature_avg.values
print(temperature_avg_seq,temperature_avg_seq.shape)

# %%
window_size=100

X=[]
Y=[]
for i in range(len(temperature_avg_seq)-window_size):
  X.append(temperature_avg_seq[i:i+window_size])
  Y.append(temperature_avg_seq[i+window_size])

# %%
X=np.array(X)
Y=np.array(Y)

# %%
print("X Shape",X.shape)
print("Y Shape",Y.shape)

# %%
X

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
print("X_train Shape",X_train.shape)
print("X_test Shape",X_test.shape)
print("Y_train Shape",Y_train.shape)
print("Y_test Shape",Y_test.shape)

# %%
X_train

# %%
from sklearn.preprocessing import StandardScaler
MinMax=MinMaxScaler()
X_train_Scaled=MinMax.fit_transform(X_train.reshape(-1,1))
X_test_Scaled=MinMax.transform(X_test.reshape(-1,1))

# %%
X_train=X_train_Scaled.reshape(X_train.shape[0],100)

# %%
X_test=X_test_Scaled.reshape(X_test.shape[0],100)

# %%
print("X_train Shape",X_train.shape)
print("X_test Shape",X_test.shape)
print("Y_train Shape",Y_train.shape)
print("Y_test Shape",Y_test.shape)

# %%
maxLength=6
upgraded_naive_model=Sequential()
upgraded_naive_model.add(LSTM(128,return_sequences=True,input_shape=(window_size,1)))
upgraded_naive_model.add(Dropout(0.2))
upgraded_naive_model.add(LSTM(100,return_sequences=True))
upgraded_naive_model.add(Dropout(0.2))
upgraded_naive_model.add(LSTM(100,return_sequences=True))
upgraded_naive_model.add(Dropout(0.2))
upgraded_naive_model.add(LSTM(100))
upgraded_naive_model.add(Dropout(0.2))

upgraded_naive_model.add(Dense(64,activation="relu"))
upgraded_naive_model.add(Dropout(0.2))


upgraded_naive_model.add(Dense(1))

# %%
upgraded_naive_model.summary()

# %%
upgraded_naive_model.compile(optimizer="adam",loss="mse",metrics=["mae"])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint(
    "temperature_best_min_MinMax.keras",
    monitor = "val_loss",
    mode = "min",
    save_best_only = True,
    verbose = 1
)

# %%
X_test.shape, Y_test.shape

# %%
history=upgraded_naive_model.fit(np.array(X_train).reshape(-1,window_size,1),Y_train,epochs=50,batch_size=16,validation_data=(X_test,Y_test),callbacks=[checkpoint])

# %%
plot_loss_curves(history)

# %%
from tensorflow.keras.models import load_model
best_model=load_model("/kaggle/working/temperature_best_min_MinMax.keras")
# best_model.save("upgraded_naive_model_best_avg.h5")

# %%
from meteostat import Point, Daily
import datetime


location = Point( 23.0215374, 72.5800568)
start = datetime.datetime(2024, 6, 1)
end = datetime.datetime(2024, 6, 30)

# Get historical data
data = Daily(location, start, end)
data = data.fetch()

print(data)

# %%
print(data.shape)

# %%
next_6_months_temp=data["tmin"]

# %%
plt.plot(next_6_months_temp.values.flatten())

# %%
location = Point( 23.0215374, 72.5800568)
start = datetime.datetime(2024, 2, 22)
end = datetime.datetime(2024, 5, 31)

# Get historical data
data_for_model = Daily(location, start, end)
data_for_model = data_for_model.fetch()

print(data_for_model)

# %%
data_for_model["tmin"].values

# %%
data_for_model=MinMax.transform(np.array(data_for_model["tmin"].values).reshape(-1,1))

# %%
data_for_model=data_for_model.reshape(1,100,1)

# %%
data_for_model=data_for_model.flatten()
data_for_model

# %%
copied=data_for_model.copy()
copied=copied[1:]
copied = np.append(copied, 1.2)
copied

# %%
output=[]
for i in range(30):
    print(data_for_model)

    prediction = best_model.predict(np.array(data_for_model).reshape(-1, window_size, 1))
    
    output.append(prediction)
    data_for_model = np.append(data_for_model[1:], prediction)

# %%
next_6_months_temp=list(next_6_months_temp.values)

# %%
print("Len Output:",len(output))
print("Len next_6_months_temp:",len(next_6_months_temp))

# %%
list(np.array(output).flatten())

# %%
# Plot the two arrays
import matplotlib.pyplot as plt

plt.plot(list(next_6_months_temp), label="Actual Temperature")
plt.plot(list(np.array(output).flatten()), label="Predicted Temperature")
plt.legend()
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Actual vs Predicted Temperature")
plt.show()

# %%
from sklearn.metrics import r2_score,mean_squared_error
mean_squared_error(list(next_6_months_temp),list(np.array(output).flatten()))

# %%
y_prediction_x=best_model.predict(np.array(X_test).reshape(-1,window_size,1))

# %%
len(y_prediction_x)

# %%
y_pred_final=[]
for i in y_prediction_x:
  # print(i)
  y_pred_final.append(MinMax.inverse_transform(i.reshape(-1,1))[0,0])

# %%
y_true_final=[]

for i in Y_test:
  # print(i)
  y_true_final.append(MinMax_Loaded.inverse_transform(np.array(i).reshape(-1,1))[0,0])

# %%
y_true_final[0], y_pred_final[0], Y_test[0],y_prediction_x[0]

# %%
len(y_true_final)

# %%
mean_squared_error(Y_test,y_prediction_x)

# %%
len(y_true_final)

# %%
# Plot the two arrays
import matplotlib.pyplot as plt

plt.plot(Y_test, label="Actual Temperature")
plt.plot(y_prediction_x, label="Predicted Temperature")
plt.legend()
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Actual vs Predicted Temperature")
plt.show()

# %%
import pickle as pkl

pkl.dump(MinMax,open("MinMaxScaler_min.pkl",'wb'))

# %%
MinMax_Loaded=pkl.load(open("/kaggle/working/MinMax_Avg.pkl","rb"))

# %% [markdown]
# # 4 FEATURES , 100 WINDOW SIZE ,BATCH SIZE=32 , NEXT PREDICTION

# %%
import numpy as np

# %%
from meteostat import Point, Daily
import datetime


location = Point( 23.0215374, 72.5800568)
start = datetime.datetime(2000, 1, 1)
end = datetime.datetime(2024, 12, 31)

# Get historical data
data = Daily(location, start, end)
data = data.fetch()

print(data)
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2000-01-01  21.8  12.5  29.6   0.0   NaN    NaN   NaN   NaN     NaN   NaN
# 2000-01-02  21.4  15.1  30.0   0.0   NaN    NaN   NaN   NaN     NaN   NaN
# 2000-01-03  20.4   NaN  30.3   0.0   NaN    NaN   NaN   NaN     NaN   NaN
# 2000-01-04  18.5  11.8  30.2   0.0   NaN    NaN   NaN   NaN     NaN   NaN
# 2000-01-05  20.7   9.6  29.4   0.0   NaN    NaN   NaN   NaN     NaN   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-12-27  21.8  19.0  27.0   0.0   NaN  308.0   6.5   NaN  1015.3   NaN
# 2024-12-28  20.3  16.0  25.8   0.0   NaN  343.0   6.4   NaN  1016.3   NaN
# 2024-12-29  19.9  15.0  25.0   0.0   NaN   25.0  15.5   NaN  1017.5   NaN
# 2024-12-30  19.5  14.0  26.4   0.0   NaN   22.0   9.4   NaN  1017.0   NaN
# 2024-12-31  20.5  14.0  27.4   0.0   NaN   14.0   6.5   NaN  1016.8   NaN
#
# [9132 rows x 10 columns]
# RuntimeWarning: invalid value encountered in greater
# RuntimeWarning: invalid value encountered in less
# RuntimeWarning: invalid value encountered in greater

# %%
data.reset_index(inplace=True)

# %%
target_column="tavg"

# %%
temperature_max=data[["time",target_column]]

# %%
temperature_max['month'] = temperature_max['time'].dt.month
temperature_max['dayofyear'] = temperature_max['time'].dt.dayofyear  


seasonal_mean = temperature_max.groupby('month')[target_column].transform('mean') 
temperature_max[target_column] = temperature_max[target_column].fillna(seasonal_mean)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print("TOTAL NULL VALUES IN DATASET:",temperature_max.isnull().sum())
# Out:
# TOTAL NULL VALUES IN DATASET: time         0
# tavg         0
# month        0
# dayofyear    0
# dtype: int64

# %%
temperature_max.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9132 entries, 0 to 9131
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   time       9132 non-null   datetime64[ns]
#  1   tavg       9132 non-null   float64
#  2   month      9132 non-null   int32
#  3   dayofyear  9132 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(2)
# memory usage: 214.2 KB

# %%
_## we use another 3 feature sin of year and cos of year

# "sin_day_of_year"-->Sine transformation for seasonality	Float (between -1 and 1)	0.75
# "cos_day_of_year"-->Cosine transformation for seasonality	Float (between -1 and 1)	-0.43

temperature_max['sin_day_of_year'] = np.round(np.sin(2 * np.pi * temperature_max['dayofyear'] / 365),4)
temperature_max['cos_day_of_year'] = np.round(np.cos(2 * np.pi * temperature_max['dayofyear'] / 365),4)
# Out:
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
temperature_max
# Out:
#            time  tavg  month  dayofyear  sin_day_of_year  cos_day_of_year
# 0    2000-01-01  21.8      1          1           0.0172           0.9999
# 1    2000-01-02  21.4      1          2           0.0344           0.9994
# 2    2000-01-03  20.4      1          3           0.0516           0.9987
# 3    2000-01-04  18.5      1          4           0.0688           0.9976
# 4    2000-01-05  20.7      1          5           0.0860           0.9963
# ...         ...   ...    ...        ...              ...              ...
# 9127 2024-12-27  21.8     12        362          -0.0516           0.9987
# 9128 2024-12-28  20.3     12        363          -0.0344           0.9994
# 9129 2024-12-29  19.9     12        364          -0.0172           0.9999
# 9130 2024-12-30  19.5     12        365           0.0000           1.0000
# 9131 2024-12-31  20.5     12        366           0.0172           0.9999
#
# [9132 rows x 6 columns]

# %%
temperature_max_processed=temperature_max[[target_column,"sin_day_of_year","cos_day_of_year","month"]]

# %%
# temperature_max_processed[['tmax', 'sin_day_of_year', 'cos_day_of_year', 'month']].iloc[:100].values.shape  # shape (100, 4)
temperature_max_processed[target_column].iloc[100]  # scalar (next day's tmax)
# Out:
# 31.5

# %%
window_size=100

X=[]
Y=[]

for i in range(len(temperature_max_processed)-window_size):
    X.append(temperature_max_processed[[target_column, 'sin_day_of_year', 'cos_day_of_year', 'month']].iloc[i:i+window_size].values)
    Y.append(temperature_max_processed[target_column].iloc[i+window_size])

# %%
X=np.array(X)
Y=np.array(Y)

# %%
print("X Shape:",X.shape)
print("Y Shape:",Y.shape)
# Out:
# X Shape: (9032, 100, 4)
# Y Shape: (9032,)

# %% [markdown]
# # SPLITING THE DATA INTO TRAIN AND TEST

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
print("X_train Shape",X_train.shape)
print("X_test Shape",X_test.shape)
print("Y_train Shape",Y_train.shape)
print("Y_test Shape",Y_test.shape)
# Out:
# X_train Shape (7225, 100, 4)
# X_test Shape (1807, 100, 4)
# Y_train Shape (7225,)
# Y_test Shape (1807,)

# %%
from sklearn.preprocessing import StandardScaler
Standard=StandardScaler()
X_train_Scaled=Standard.fit_transform(X_train.reshape(-1,1))
X_test_Scaled=Standard.transform(X_test.reshape(-1,1))

# %%
X_train=X_train_Scaled.reshape(X_train.shape[0],100,4)
X_test=X_test_Scaled.reshape(X_test.shape[0],100,4)

# %%
Y_train=Y_train_Scaled
Y_test=Y_test_Scaled

# %%
print("X_train Shape",X_train.shape)
print("X_test Shape",X_test.shape)
print("Y_train Shape",Y_train.shape)
print("Y_test Shape",Y_test.shape)
# Out:
# X_train Shape (7225, 100, 4)
# X_test Shape (1807, 100, 4)
# Y_train Shape (7225,)
# Y_test Shape (1807,)

# %%
print(X_train[0],Y_train[0])
# Out:
# [[ 1.96122915e+00 -7.93926464e-01 -8.40183336e-01  5.60084171e-04]
#  [ 1.95057334e+00 -7.95556803e-01 -8.39330871e-01  5.60084171e-04]
#  [ 2.07844306e+00 -7.97165830e-01 -8.38457094e-01  5.60084171e-04]
#  [ 2.02516401e+00 -7.98753546e-01 -8.37551350e-01  1.07118186e-01]
#  [ 2.00385239e+00 -8.00341262e-01 -8.36624295e-01  1.07118186e-01]
#  [ 1.95899211e+00 -8.01897010e-01 -8.35654616e-01  1.07118186e-01]
#  [ 1.95899211e+00 -8.03442102e-01 -8.34674282e-01  1.07118186e-01]
#  [ 1.95899211e+00 -8.04976539e-01 -8.33661980e-01  1.07118186e-01]
#  [ 1.96122915e+00 -8.06489664e-01 -8.32617710e-01  1.07118186e-01]
#  [ 1.95899211e+00 -8.07981477e-01 -8.31552129e-01  1.07118186e-01]
#  [ 1.87598267e+00 -8.09451979e-01 -8.30465237e-01  1.07118186e-01]
#  [ 1.95899211e+00 -8.10911825e-01 -8.29346377e-01  1.07118186e-01]
#  [ 1.84401524e+00 -8.12350360e-01 -8.28206205e-01  1.07118186e-01]
#  [ 1.91860591e+00 -8.13767582e-01 -8.27044722e-01  1.07118186e-01]
#  [ 1.95899211e+00 -8.15163493e-01 -8.25851271e-01  1.07118186e-01]
#  [ 1.95899211e+00 -8.16538093e-01 -8.24636509e-01  1.07118186e-01]
#  [ 1.97188496e+00 -8.17891381e-01 -8.23400435e-01  1.07118186e-01]
#  [ 1.97188496e+00 -8.19223357e-01 -8.22143049e-01  1.07118186e-01]
#  [ 2.00385239e+00 -8.20534022e-01 -8.20853696e-01  1.07118186e-01]
#  [ 1.95899211e+00 -8.21823375e-01 -8.19553687e-01  1.07118186e-01]
#  [ 1.98254077e+00 -8.23091416e-01 -8.18221711e-01  1.07118186e-01]
#  [ 1.98254077e+00 -8.24327490e-01 -8.16879079e-01  1.07118186e-01]
#  [ 1.95899211e+00 -8.25552908e-01 -8.15504479e-01  1.07118186e-01]
#  [ 1.95899211e+00 -8.26746359e-01 -8.14108568e-01  1.07118186e-01]
#  [ 1.74811295e+00 -8.27918498e-01 -8.12702001e-01  1.07118186e-01]
#  [ 1.95057334e+00 -8.29058670e-01 -8.11274123e-01  1.07118186e-01]
#  [ 1.97188496e+00 -8.30188186e-01 -8.09824933e-01  1.07118186e-01]
#  [ 1.95899211e+00 -8.31285734e-01 -8.08354431e-01  1.07118186e-01]
#  [ 2.09975468e+00 -8.32351315e-01 -8.06862617e-01  1.07118186e-01]
#  [ 1.95899211e+00 -8.33406240e-01 -8.05360148e-01  1.07118186e-01]
#  [ 1.95899211e+00 -8.34418542e-01 -8.03825711e-01  1.07118186e-01]
#  [ 1.86532686e+00 -8.35409533e-01 -8.02291275e-01  1.07118186e-01]
#  [ 1.89729429e+00 -8.36379211e-01 -8.00724871e-01  1.07118186e-01]
#  [ 1.97188496e+00 -8.37316923e-01 -7.99158467e-01  1.07118186e-01]
#  [ 1.92915674e+00 -8.38233322e-01 -7.97560095e-01  2.13676287e-01]
#  [ 2.00385239e+00 -8.39117755e-01 -7.95961724e-01  2.13676287e-01]
#  [ 2.05713144e+00 -8.39980875e-01 -7.94331385e-01  2.13676287e-01]
#  [ 2.05713144e+00 -8.40801373e-01 -7.92701046e-01  2.13676287e-01]
#  [ 2.13172211e+00 -8.41611214e-01 -7.91049395e-01  2.13676287e-01]
#  [ 1.92915674e+00 -8.42378432e-01 -7.89387089e-01  2.13676287e-01]
#  [ 1.97188496e+00 -8.43124339e-01 -7.87703471e-01  2.13676287e-01]
#  [ 2.02516401e+00 -8.43838278e-01 -7.86019853e-01  2.13676287e-01]
#  [ 2.02516401e+00 -8.44520250e-01 -7.84314923e-01  2.13676287e-01]
#  [ 2.02516401e+00 -8.45180911e-01 -7.82599338e-01  2.13676287e-01]
#  [ 1.92915674e+00 -8.45809603e-01 -7.80883752e-01  2.13676287e-01]
#  [ 2.04647563e+00 -8.46406329e-01 -7.79146855e-01  2.13676287e-01]
#  [ 2.02516401e+00 -8.46971087e-01 -7.77399302e-01  2.13676287e-01]
#  [ 1.97188496e+00 -8.47503877e-01 -7.75651749e-01  2.13676287e-01]
#  [ 1.88663848e+00 -8.48015356e-01 -7.73882885e-01  2.13676287e-01]
#  [ 1.95057334e+00 -8.48484212e-01 -7.72114020e-01  2.13676287e-01]
#  [ 1.98254077e+00 -8.48931756e-01 -7.70334500e-01  2.13676287e-01]
#  [ 1.99319658e+00 -8.49347332e-01 -7.68544324e-01  2.13676287e-01]
#  [ 1.92915674e+00 -8.49730941e-01 -7.66754148e-01  2.13676287e-01]
#  [ 1.92915674e+00 -8.50082583e-01 -7.64953316e-01  2.13676287e-01]
#  [ 1.83335943e+00 -8.50402258e-01 -7.63152484e-01  2.13676287e-01]
#  [ 1.92915674e+00 -8.50700620e-01 -7.61340996e-01  2.13676287e-01]
#  [ 1.78008038e+00 -8.50956360e-01 -7.59518853e-01  2.13676287e-01]
#  [ 1.91860591e+00 -8.51190787e-01 -7.57696709e-01  2.13676287e-01]
#  [ 1.92915674e+00 -8.51382592e-01 -7.55874566e-01  2.13676287e-01]
#  [ 1.92915674e+00 -8.51553085e-01 -7.54052422e-01  2.13676287e-01]
#  [ 1.92915674e+00 -8.51680955e-01 -7.52219623e-01  2.13676287e-01]
#  [ 1.91860591e+00 -8.51787513e-01 -7.50386824e-01  2.13676287e-01]
#  [ 1.92915674e+00 -8.51851448e-01 -7.48554024e-01  2.13676287e-01]
#  [ 1.76942457e+00 -8.51894071e-01 -7.46721225e-01  2.13676287e-01]
#  [ 1.81204781e+00 -8.51904727e-01 -7.44888426e-01  3.20234388e-01]
#  [ 1.60989707e+00 -8.51883415e-01 -7.43055626e-01  3.20234388e-01]
#  [ 1.64155485e+00 -8.51830136e-01 -7.41222827e-01  3.20234388e-01]
#  [ 1.60989707e+00 -8.51734234e-01 -7.39390028e-01  3.20234388e-01]
#  [ 1.15138758e+00 -8.51617020e-01 -7.37557228e-01  3.20234388e-01]
#  [ 1.41778283e+00 -8.51467839e-01 -7.35724429e-01  3.20234388e-01]
#  [ 1.60989707e+00 -8.51286690e-01 -7.33902285e-01  3.20234388e-01]
#  [ 1.47106188e+00 -8.51073574e-01 -7.32080142e-01  3.20234388e-01]
#  [ 1.76942457e+00 -8.50828490e-01 -7.30268654e-01  3.20234388e-01]
#  [ 1.60989707e+00 -8.50551439e-01 -7.28446511e-01  3.20234388e-01]
#  [ 1.60989707e+00 -8.50253076e-01 -7.26645679e-01  3.20234388e-01]
#  [ 1.60989707e+00 -8.49912090e-01 -7.24834191e-01  3.20234388e-01]
#  [ 1.60989707e+00 -8.49539137e-01 -7.23044015e-01  3.20234388e-01]
#  [ 1.22597825e+00 -8.49144872e-01 -7.21253839e-01  3.20234388e-01]
#  [ 1.26860149e+00 -8.48718640e-01 -7.19474318e-01  3.20234388e-01]
#  [ 1.22597825e+00 -8.48249784e-01 -7.17694798e-01  3.20234388e-01]
#  [ 1.13007596e+00 -8.47759617e-01 -7.15925934e-01  3.20234388e-01]
#  [ 1.05548529e+00 -8.47237482e-01 -7.14167725e-01  3.20234388e-01]
#  [ 1.11942015e+00 -8.46694036e-01 -7.12420172e-01  3.20234388e-01]
#  [ 1.17269920e+00 -8.46107966e-01 -7.10683275e-01  3.20234388e-01]
#  [ 1.06614110e+00 -8.45500585e-01 -7.08946378e-01  3.20234388e-01]
#  [ 1.60989707e+00 -8.44850580e-01 -7.07230793e-01  3.20234388e-01]
#  [ 1.13007596e+00 -8.44179264e-01 -7.05525863e-01  3.20234388e-01]
#  [ 1.34319216e+00 -8.43486637e-01 -7.03831589e-01  3.20234388e-01]
#  [ 1.60989707e+00 -8.42751386e-01 -7.02147971e-01  3.20234388e-01]
#  [ 1.60989707e+00 -8.41994823e-01 -7.00475009e-01  3.20234388e-01]
#  [ 1.60989707e+00 -8.41206293e-01 -6.98812703e-01  3.20234388e-01]
#  [ 1.60989707e+00 -8.40396452e-01 -6.97171708e-01  3.20234388e-01]
#  [ 1.60989707e+00 -8.39554643e-01 -6.95541369e-01  3.20234388e-01]
#  [ 1.60989707e+00 -8.38680866e-01 -6.93932341e-01  3.20234388e-01]
#  [ 1.36450378e+00 -8.37785778e-01 -6.92333970e-01  3.20234388e-01]
#  [ 1.10429128e+00 -8.36858723e-01 -6.90746254e-01  4.26792490e-01]
#  [ 1.10429128e+00 -8.35899700e-01 -6.89179850e-01  4.26792490e-01]
#  [ 1.10429128e+00 -8.34919365e-01 -6.87634758e-01  4.26792490e-01]
#  [ 1.10429128e+00 -8.33917719e-01 -6.86100321e-01  4.26792490e-01]
#  [ 1.10429128e+00 -8.32884106e-01 -6.84587196e-01  4.26792490e-01]] 16.5

# %% [markdown]
# # IMPORTING IMPORTANT LIBRARIES FOR MAKING DEEP LEARNING MODEL WITH LSTM

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from keras.layers import Dense,LSTM,Dropout,Flatten,BatchNormalization
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
checkpoint = ModelCheckpoint(
    "temperature_avg_Standard.keras",
    monitor = "val_loss",
    mode = "min",
    save_best_only = True,
    verbose = 1
)

earlyStop=EarlyStopping(
    monitor="val_loss",
    patience=3
)

# %% [markdown]
# # INITIALIZING MODEL STRUCTURE

# %%
maxLength=6
upgraded_naive_model1=Sequential()
upgraded_naive_model1.add(LSTM(128,return_sequences=True,input_shape=(window_size,4)))
upgraded_naive_model1.add(BatchNormalization())
upgraded_naive_model1.add(Dropout(0.2))

upgraded_naive_model1.add(LSTM(100,return_sequences=True))
upgraded_naive_model1.add(BatchNormalization())
upgraded_naive_model1.add(Dropout(0.2))

upgraded_naive_model1.add(LSTM(100,return_sequences=True))
upgraded_naive_model1.add(BatchNormalization())
upgraded_naive_model1.add(Dropout(0.2))

upgraded_naive_model1.add(LSTM(100))
upgraded_naive_model1.add(BatchNormalization())
upgraded_naive_model1.add(Dropout(0.2))

upgraded_naive_model1.add(Dense(128,activation="relu"))
upgraded_naive_model1.add(BatchNormalization())
upgraded_naive_model1.add(Dropout(0.2))

upgraded_naive_model1.add(Dense(64,activation="relu"))
upgraded_naive_model1.add(BatchNormalization())
upgraded_naive_model1.add(Dropout(0.2))

upgraded_naive_model1.add(Dense(1))
# Out:
# UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
upgraded_naive_model1.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_8 (LSTM)                        │ (None, 100, 128)            │          68,096 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_12               │ (None, 100, 128)            │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 100, 128)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_9 (LSTM)                        │ (None, 100, 100)            │          91,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_13               │ (None, 100, 100)            │             400 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 100, 100)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_10 (LSTM)                       │ (None, 100, 100)            │          80,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_14               │ (None, 100, 100)            │             400 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 100, 100)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_11 (LSTM)                       │ (None, 100)                 │          80,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_15               │ (None, 100)                 │             400 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │          12,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_16               │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_16 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_17               │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_17 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 344,225 (1.31 MB)
#  Trainable params: 342,985 (1.31 MB)
#  Non-trainable params: 1,240 (4.84 KB)

# %%
upgraded_naive_model1.compile(optimizer="adam",loss="mse",metrics=["mae"])

# %%
history=upgraded_naive_model1.fit(np.array(X_train).reshape(-1,window_size,4),Y_train,epochs=50,batch_size=32,validation_data=(X_test,Y_test),callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 224/226 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 734.1039 - mae: 26.8905
# Epoch 1: val_loss improved from inf to 870.31177, saving model to temperature_avg_Standard.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 15s 28ms/step - loss: 733.2816 - mae: 26.8748 - val_loss: 870.3118 - val_mae: 29.1367
# Epoch 2/50
# 224/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 376.7950 - mae: 18.8718
# Epoch 2: val_loss improved from 870.31177 to 198.83035, saving model to temperature_avg_Standard.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 375.2871 - mae: 18.8242 - val_loss: 198.8304 - val_mae: 13.6674
# Epoch 3/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 47.6895 - mae: 5.8897
# Epoch 3: val_loss improved from 198.83035 to 22.90940, saving model to temperature_avg_Standard.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 47.6202 - mae: 5.8840 - val_loss: 22.9094 - val_mae: 4.2340
# Epoch 4/50
# 224/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 14.7366 - mae: 3.0223
# Epoch 4: val_loss improved from 22.90940 to 3.44903, saving model to temperature_avg_Standard.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 14.7303 - mae: 3.0218 - val_loss: 3.4490 - val_mae: 1.4686
# Epoch 5/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 13.0181 - mae: 2.8576
# Epoch 5: val_loss did not improve from 3.44903
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 13.0158 - mae: 2.8575 - val_loss: 9.6590 - val_mae: 2.7156
# Epoch 6/50
# 224/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 11.7185 - mae: 2.7337
# Epoch 6: val_loss did not improve from 3.44903
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 11.7170 - mae: 2.7335 - val_loss: 4.2881 - val_mae: 1.6892
# Epoch 7/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 11.7580 - mae: 2.6922
# Epoch 7: val_loss improved from 3.44903 to 3.33225, saving model to temperature_avg_Standard.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 11.7566 - mae: 2.6921 - val_loss: 3.3323 - val_mae: 1.3650
# Epoch 8/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 10.1875 - mae: 2.5137
# Epoch 8: val_loss did not improve from 3.33225
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 10.1882 - mae: 2.5139 - val_loss: 3.5052 - val_mae: 1.5159
# Epoch 9/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 9.4558 - mae: 2.4276
# Epoch 9: val_loss improved from 3.33225 to 3.11347, saving model to temperature_avg_Standard.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 9.4555 - mae: 2.4276 - val_loss: 3.1135 - val_mae: 1.4444
# Epoch 10/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.9417 - mae: 2.3672
# Epoch 10: val_loss did not improve from 3.11347
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 8.9401 - mae: 2.3670 - val_loss: 6.9767 - val_mae: 2.1393
# Epoch 11/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 8.7604 - mae: 2.3487
# Epoch 11: val_loss did not improve from 3.11347
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 8.7590 - mae: 2.3484 - val_loss: 6.1263 - val_mae: 2.0632
# Epoch 12/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 7.9337 - mae: 2.2504
# Epoch 12: val_loss did not improve from 3.11347
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 7.9337 - mae: 2.2503 - val_loss: 3.9195 - val_mae: 1.6264
# Epoch 13/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.6842 - mae: 2.1953
# Epoch 13: val_loss improved from 3.11347 to 1.77696, saving model to temperature_avg_Standard.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 7.6834 - mae: 2.1952 - val_loss: 1.7770 - val_mae: 1.0069
# Epoch 14/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.9712 - mae: 2.0958
# Epoch 14: val_loss did not improve from 1.77696
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 6.9720 - mae: 2.0959 - val_loss: 8.0399 - val_mae: 2.5825
# Epoch 15/50
# 224/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 7.2002 - mae: 2.1267
# Epoch 15: val_loss did not improve from 1.77696
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 7.1996 - mae: 2.1267 - val_loss: 2.9125 - val_mae: 1.3594
# Epoch 16/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.6324 - mae: 2.0380
# Epoch 16: val_loss did not improve from 1.77696
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 6.6329 - mae: 2.0381 - val_loss: 9.1007 - val_mae: 2.6767
# Epoch 17/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.6111 - mae: 2.0438
# Epoch 17: val_loss did not improve from 1.77696
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 6.6100 - mae: 2.0436 - val_loss: 6.4480 - val_mae: 2.2290
# Epoch 18/50
# 224/226 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 6.6050 - mae: 2.0342
# Epoch 18: val_loss did not improve from 1.77696
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 6.6038 - mae: 2.0341 - val_loss: 2.3879 - val_mae: 1.2957
# Epoch 19/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.5884 - mae: 2.0348
# Epoch 19: val_loss did not improve from 1.77696
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 6.5876 - mae: 2.0347 - val_loss: 3.8279 - val_mae: 1.7095
# Epoch 20/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.0610 - mae: 1.9573
# Epoch 20: val_loss improved from 1.77696 to 1.68409, saving model to temperature_avg_Standard.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 6.0619 - mae: 1.9574 - val_loss: 1.6841 - val_mae: 1.0024
# Epoch 21/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.3278 - mae: 1.9911
# Epoch 21: val_loss did not improve from 1.68409
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 6.3279 - mae: 1.9912 - val_loss: 2.3781 - val_mae: 1.1798
# Epoch 22/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.8229 - mae: 1.9094
# Epoch 22: val_loss did not improve from 1.68409
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.8236 - mae: 1.9095 - val_loss: 4.5923 - val_mae: 1.6580
# Epoch 23/50
# 224/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.1733 - mae: 1.9717
# Epoch 23: val_loss did not improve from 1.68409
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 6.1742 - mae: 1.9718 - val_loss: 2.3082 - val_mae: 1.1896
# Epoch 24/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.0747 - mae: 1.9738
# Epoch 24: val_loss did not improve from 1.68409
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 6.0741 - mae: 1.9736 - val_loss: 2.6838 - val_mae: 1.3548
# Epoch 25/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 6.2639 - mae: 1.9876
# Epoch 25: val_loss did not improve from 1.68409
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 6.2626 - mae: 1.9874 - val_loss: 2.8484 - val_mae: 1.4396
# Epoch 26/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.8931 - mae: 1.9227
# Epoch 26: val_loss did not improve from 1.68409
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 5.8943 - mae: 1.9230 - val_loss: 6.8295 - val_mae: 2.2403
# Epoch 27/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.7389 - mae: 1.8994
# Epoch 27: val_loss did not improve from 1.68409
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.7394 - mae: 1.8995 - val_loss: 4.9406 - val_mae: 1.8167
# Epoch 28/50
# 224/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.7357 - mae: 1.9110
# Epoch 28: val_loss did not improve from 1.68409
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.7354 - mae: 1.9109 - val_loss: 5.0222 - val_mae: 1.9848
# Epoch 29/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.6936 - mae: 1.8960
# Epoch 29: val_loss did not improve from 1.68409
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 5.6937 - mae: 1.8961 - val_loss: 3.7915 - val_mae: 1.5810
# Epoch 30/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.3780 - mae: 1.8431
# Epoch 30: val_loss improved from 1.68409 to 1.66276, saving model to temperature_avg_Standard.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 5.3792 - mae: 1.8433 - val_loss: 1.6628 - val_mae: 1.0007
# Epoch 31/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.7074 - mae: 1.9016
# Epoch 31: val_loss did not improve from 1.66276
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 5.7063 - mae: 1.9014 - val_loss: 1.7361 - val_mae: 1.0157
# Epoch 32/50
# 224/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.4265 - mae: 1.8303
# Epoch 32: val_loss did not improve from 1.66276
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.4272 - mae: 1.8305 - val_loss: 5.3529 - val_mae: 2.0525
# Epoch 33/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.7777 - mae: 1.9097
# Epoch 33: val_loss did not improve from 1.66276
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.7774 - mae: 1.9097 - val_loss: 2.6426 - val_mae: 1.3782
# Epoch 34/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.2887 - mae: 1.8018
# Epoch 34: val_loss improved from 1.66276 to 1.65873, saving model to temperature_avg_Standard.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.2911 - mae: 1.8023 - val_loss: 1.6587 - val_mae: 0.9594
# Epoch 35/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.5480 - mae: 1.8681
# Epoch 35: val_loss did not improve from 1.65873
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 5.5476 - mae: 1.8680 - val_loss: 3.5293 - val_mae: 1.6184
# Epoch 36/50
# 224/226 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 5.5274 - mae: 1.8818
# Epoch 36: val_loss did not improve from 1.65873
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 5.5270 - mae: 1.8816 - val_loss: 2.2094 - val_mae: 1.1173
# Epoch 37/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.6510 - mae: 1.8938
# Epoch 37: val_loss did not improve from 1.65873
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.6508 - mae: 1.8937 - val_loss: 1.9143 - val_mae: 1.0978
# Epoch 38/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.3790 - mae: 1.8431
# Epoch 38: val_loss did not improve from 1.65873
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.3818 - mae: 1.8436 - val_loss: 1.7994 - val_mae: 1.0112
# Epoch 39/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.5788 - mae: 1.8744
# Epoch 39: val_loss did not improve from 1.65873
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.5787 - mae: 1.8744 - val_loss: 1.7054 - val_mae: 1.0022
# Epoch 40/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.1396 - mae: 1.7975
# Epoch 40: val_loss did not improve from 1.65873
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.1403 - mae: 1.7977 - val_loss: 1.8272 - val_mae: 1.0281
# Epoch 41/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.4423 - mae: 1.8351
# Epoch 41: val_loss improved from 1.65873 to 1.31956, saving model to temperature_avg_Standard.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.4414 - mae: 1.8351 - val_loss: 1.3196 - val_mae: 0.8588
# Epoch 42/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.7010 - mae: 1.8913
# Epoch 42: val_loss did not improve from 1.31956
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.6997 - mae: 1.8911 - val_loss: 4.4449 - val_mae: 1.8506
# Epoch 43/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.4413 - mae: 1.8717
# Epoch 43: val_loss did not improve from 1.31956
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.4415 - mae: 1.8716 - val_loss: 3.3229 - val_mae: 1.5635
# Epoch 44/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.2872 - mae: 1.8240
# Epoch 44: val_loss did not improve from 1.31956
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.2877 - mae: 1.8241 - val_loss: 1.7536 - val_mae: 1.0571
# Epoch 45/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.4302 - mae: 1.8455
# Epoch 45: val_loss did not improve from 1.31956
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.4295 - mae: 1.8454 - val_loss: 2.4338 - val_mae: 1.2056
# Epoch 46/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.4158 - mae: 1.8322
# Epoch 46: val_loss did not improve from 1.31956
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.4153 - mae: 1.8321 - val_loss: 1.6696 - val_mae: 1.0302
# Epoch 47/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.2579 - mae: 1.8194
# Epoch 47: val_loss did not improve from 1.31956
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.2581 - mae: 1.8194 - val_loss: 3.1181 - val_mae: 1.4888
# Epoch 48/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.2157 - mae: 1.8117
# Epoch 48: val_loss did not improve from 1.31956
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.2151 - mae: 1.8116 - val_loss: 10.9555 - val_mae: 3.0582
# Epoch 49/50
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.5704 - mae: 1.8770
# Epoch 49: val_loss did not improve from 1.31956
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 5.5687 - mae: 1.8767 - val_loss: 2.0846 - val_mae: 1.1068
# Epoch 50/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 5.2526 - mae: 1.8313
# Epoch 50: val_loss did not improve from 1.31956
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 5.2525 - mae: 1.8312 - val_loss: 1.4970 - val_mae: 0.9339

# %%
plot_loss_curves(history)

# %%
from tensorflow.keras.models import load_model
best_model=load_model("/kaggle/working/temperature_avg_Standard.keras")
# best_model.save("upgraded_naive_model_best_avg.h5")

# %% [markdown]
# # MANUAL TESTING ON RANDOM DATA

# %%
from meteostat import Point, Daily
import datetime


location = Point( 23.0215374, 72.5800568)
start = datetime.datetime(2024, 6, 1)
end = datetime.datetime(2024, 6, 30)

# Get historical data
data = Daily(location, start, end)
data = data.fetch()

print(data)
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2024-06-01  34.5  30.0  41.6   0.0   NaN  203.0  14.7   NaN  1003.3   NaN
# 2024-06-02  34.5  30.0  41.4   0.0   NaN  212.0  10.9   NaN  1004.5   NaN
# 2024-06-03  34.8  30.0  41.6   0.0   NaN  220.0  11.6   NaN  1003.9   NaN
# 2024-06-04  34.8  30.0  41.4   0.0   NaN  227.0  15.0   NaN  1004.4   NaN
# 2024-06-05  34.5  29.0  41.4   0.0   NaN  223.0  14.3   NaN  1005.0   NaN
# 2024-06-06  34.6  29.0  41.6   0.0   NaN  227.0  12.6   NaN  1005.7   NaN
# 2024-06-07  35.7  30.0  42.4   0.0   NaN  248.0  12.0   NaN  1003.6   NaN
# 2024-06-08  35.5  31.0  41.8   0.0   NaN  224.0  11.0   NaN  1002.4   NaN
# 2024-06-09  35.6  29.0  43.0   0.0   NaN  267.0  13.1   NaN  1001.9   NaN
# 2024-06-10  32.5  27.4  39.6   1.0   NaN  234.0  10.1   NaN  1003.5   NaN
# 2024-06-11  33.3  25.5  40.2  30.0   NaN  250.0  10.7   NaN  1003.5   NaN
# 2024-06-12  33.5  29.0  40.8   0.0   NaN  234.0  11.7   NaN  1004.0   NaN
# 2024-06-13  33.7  26.0  41.2   0.0   NaN  231.0  14.9   NaN  1003.5   NaN
# 2024-06-14  32.4  28.0  39.2   4.1   NaN  233.0  10.5   NaN  1002.8   NaN
# 2024-06-15  33.1  27.7  39.8   1.0   NaN  221.0  12.9   NaN  1002.6   NaN
# 2024-06-16  33.5  29.0  40.2   0.0   NaN  192.0  12.7   NaN  1003.0   NaN
# 2024-06-17  34.4  30.0  40.6   0.0   NaN  195.0  12.7   NaN  1003.0   NaN
# 2024-06-18  34.1  30.0  40.0   0.1   NaN  201.0  14.9   NaN  1002.1   NaN
# 2024-06-19  32.8  29.0  37.8   0.0   NaN  190.0  16.6   NaN   999.5   NaN
# 2024-06-20  33.6  30.0  39.2   0.0   NaN  186.0  15.3   NaN   998.1   NaN
# 2024-06-21  33.4  30.0  40.0   0.0   NaN  193.0  14.6   NaN   999.4   NaN
# 2024-06-22  33.6  29.0  40.4   0.0   NaN  207.0  10.6   NaN   999.2   NaN
# 2024-06-23  32.7  29.0  38.4   0.5   NaN  215.0   7.7   NaN   998.9   NaN
# 2024-06-24  31.3  29.0  36.4   0.3   NaN  229.0   9.4   NaN   997.9   NaN
# 2024-06-25  29.9  26.0  34.4   6.4   NaN  181.0   8.6   NaN   996.9   NaN
# 2024-06-26  32.4  29.0  36.6   0.0   NaN  180.0   8.6   NaN   996.2   NaN
# 2024-06-27  31.2  29.0  35.6   1.0   NaN  155.0  10.2   NaN   997.6   NaN
# 2024-06-28  29.3  27.0  35.6   0.8   NaN  149.0  10.8   NaN   998.7   NaN
# 2024-06-29  28.6  27.0  33.0   1.0   NaN  162.0  11.5   NaN   999.7   NaN
# 2024-06-30  27.9  25.0  31.8   5.1   NaN  167.0   9.3   NaN  1000.0   NaN
# RuntimeWarning: invalid value encountered in greater
# RuntimeWarning: invalid value encountered in less
# RuntimeWarning: invalid value encountered in greater

# %%
print(data.shape)
# Out:
# (30, 10)

# %%
next_6_months_temp=data[target_column]

# %%
plt.plot(next_6_months_temp.values.flatten())

# %%
import datetime
location = Point( 23.0215374, 72.5800568)
start = datetime.datetime(2024, 2, 22)
end = datetime.datetime(2024, 5, 31)

# Get historical data
data_for_model = Daily(location, start, end)
data_for_model = data_for_model.fetch()

print(data_for_model)
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2024-02-22  24.2  20.0  29.8   0.0   NaN  266.0  10.0   NaN  1012.2   NaN
# 2024-02-23  22.6  15.0  30.0   0.0   NaN  347.0   5.7   NaN  1013.6   NaN
# 2024-02-24  22.1  14.0  30.0   0.0   NaN  327.0   6.7   NaN  1013.6   NaN
# 2024-02-25  22.4  13.0  30.6   0.0   NaN    6.0   9.5   NaN  1013.5   NaN
# 2024-02-26  23.9  19.0  30.0   0.0   NaN   29.0  11.7   NaN  1012.1   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-05-27  35.2  29.0  45.0   0.0   NaN  221.0  13.9   NaN   999.1   NaN
# 2024-05-28  34.4  29.0  43.4   0.0   NaN  214.0  15.5   NaN   999.5   NaN
# 2024-05-29  34.1  29.0  41.4   0.0   NaN  206.0  17.7   NaN   999.8   NaN
# 2024-05-30  34.3  30.0  43.0   0.0   NaN  201.0  13.6   NaN  1001.5   NaN
# 2024-05-31  34.4  30.0  42.4   0.0   NaN  198.0  15.7   NaN  1003.3   NaN
#
# [100 rows x 10 columns]
# RuntimeWarning: invalid value encountered in greater
# RuntimeWarning: invalid value encountered in less
# RuntimeWarning: invalid value encountered in greater

# %%
data_for_model[target_column].values
# Out:
# array([24.2, 22.6, 22.1, 22.4, 23.9, 25.5, 25.8, 27.3, 28.7, 25.5, 20.1,
#        20.7, 22.2, 23.5, 24.6, 25.1, 25.5, 26.2, 27.5, 27.7, 26.9, 27.1,
#        26.8, 27.3, 28.9, 28.9, 28. , 29.2, 29.4, 28.9, 30.1, 29.7, 30.6,
#        31.3, 32.4, 32.5, 31.7, 30. , 29.2, 30.1, 30.1, 30.2, 30.1, 30.5,
#        31.1, 30.7, 32.1, 32.3, 33. , 32.2, 31.7, 31. , 31.4, 32.3, 33. ,
#        34. , 34.6, 32.6, 31. , 31.1, 31.8, 32.2, 33.3, 33.7, 32.9, 32.7,
#        33.3, 33.7, 33.1, 32.5, 32.6, 33.4, 34.5, 33.6, 33.4, 34.6, 34.8,
#        34.7, 34.3, 34.6, 35.1, 32.5, 30.4, 33.2, 35.5, 36.3, 36.8, 37.6,
#        37.4, 37.3, 37.5, 38. , 37.5, 36.1, 35.9, 35.2, 34.4, 34.1, 34.3,
#        34.4])

# %%
data_for_model.reset_index(inplace=True)

data_for_model=data_for_model[["time",target_column]]

data_for_model['month'] = data_for_model['time'].dt.month
data_for_model['dayofyear'] = data_for_model['time'].dt.dayofyear  


seasonal_mean = data_for_model.groupby('month')[target_column].transform('mean') 
data_for_model[target_column] = data_for_model[target_column].fillna(seasonal_mean) 
data_for_model['sin_day_of_year'] = np.round(np.sin(2 * np.pi * data_for_model['dayofyear'] / 365),4)
data_for_model['cos_day_of_year'] = np.round(np.cos(2 * np.pi * data_for_model['dayofyear'] / 365),4)

data_for_model=data_for_model[[target_column,"sin_day_of_year","cos_day_of_year","month"]]

# %%
data_for_model
# Out:
#     tavg  sin_day_of_year  cos_day_of_year  month
# 0   24.2           0.7909           0.6119      2
# 1   22.6           0.8014           0.5982      2
# 2   22.1           0.8115           0.5843      2
# 3   22.4           0.8215           0.5702      2
# 4   23.9           0.8312           0.5560      2
# ..   ...              ...              ...    ...
# 95  35.2           0.5596          -0.8288      5
# 96  34.4           0.5452          -0.8383      5
# 97  34.1           0.5307          -0.8475      5
# 98  34.3           0.5161          -0.8566      5
# 99  34.4           0.5012          -0.8653      5
#
# [100 rows x 4 columns]

# %%
data_for_model=Standard.transform(np.array(data_for_model.values).reshape(-1,1))

# %%
data_for_model=data_for_model.reshape(100,4)

# %%
data_for_model.shape
# Out:
# (100, 4)

# %%
data_for_model

# %%
# data_for_model=data_for_model.flatten()
# data_for_model

# %%
Y_train[:10]

# %%
from datetime import datetime,timedelta

output=[]
base_date = datetime(2024, 5, 31)
for i in range(30):
    future_date = base_date + timedelta(days=i + 1)
    day_of_year = future_date.timetuple().tm_yday
    sin_day = np.round(np.sin(2 * np.pi * day_of_year / 365),4)
    cos_day = np.round(np.cos(2 * np.pi * day_of_year / 365),4)
    month = future_date.month
  
    
    prediction = best_model.predict(data_for_model.reshape(-1, window_size, 4), verbose=1)
    predicted_temp = prediction[0][0]
    print(prediction)
    output.append(predicted_temp)

    

 
    next_input = np.array([predicted_temp, sin_day, cos_day, month])
    next_input_scaled = Standard.transform(next_input.reshape(-1,1))
    data_for_model = np.vstack([data_for_model[1:], next_input_scaled.reshape(1,4)])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# [[34.420776]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[34.354794]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[34.287888]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[34.226746]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[34.16871]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[34.112823]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[34.058342]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[34.006157]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[33.956974]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[33.91118]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[33.867718]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[33.825478]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[33.784653]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[33.74521]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[33.707115]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[33.670418]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[33.635197]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[33.601597]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[33.569725]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[33.53968]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[33.511475]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[33.48507]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[33.46038]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[33.43727]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[33.415565]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[33.395096]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[33.375603]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[33.356815]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[33.338455]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[33.32026]]

# %%
next_6_months_temp=list(next_6_months_temp.values)

# %%
print("Len Output:",len(output))
print("Len next_6_months_temp:",len(next_6_months_temp))
# Out:
# Len Output: 30
# Len next_6_months_temp: 30

# %%
output

# %%
# Plot the two arrays
import matplotlib.pyplot as plt

plt.plot(list(next_6_months_temp), label="Actual Temperature")
plt.plot(list(np.array(output).flatten()), label="Predicted Temperature")
plt.legend()
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Actual vs Predicted Temperature")
plt.show()

# %%
from sklearn.metrics import r2_score,mean_squared_error
mean_squared_error(list(next_6_months_temp),list(np.array(output).flatten()))
# Out:
# 3.539976460736595

# %%
import pickle as pkl

pkl.dump(Standard,open("Standard_Scaler_avg.pkl",'wb'))

# %% [markdown]
# # EVALUTION

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,median_absolute_error

# %%
def model_evaluation(y_true, y_pred):
    """Compute evaluation metrics."""
    mse = mean_squared_error(y_true, y_pred)
    mae=mean_absolute_error(y_true,y_pred)
    medianae=median_absolute_error(y_true,y_pred)
    
    
    metrics = {
        "Mean Sqaured Error": mse,
        "Mean Absolute Error": mae,
        "Median Absolute Error": medianae
    }
    return metrics

# %%
def display_metrics(metrics, save_path=None):
    """Stylishly display metrics using Matplotlib and optionally save the plot."""
    fig, ax = plt.subplots(figsize=(10, 4))
    ax.barh(list(metrics.keys()), list(metrics.values()), color="skyblue")
    ax.set_title("Model Evaluation Metrics", fontsize=16, fontweight="bold")
    ax.set_xlabel("Scores", fontsize=12)
    ax.set_xlim(0, 4)
    for i, v in enumerate(metrics.values()):
        ax.text(v + 0.01, i, f"{v:.2f}", color="black", va="center", fontsize=10)
    plt.tight_layout()
    
    # Save the plot if a save path is provided
    if save_path:
        fig.savefig(save_path, dpi=300, bbox_inches="tight")
        print(f"Metrics plot saved to {save_path}")
    plt.show()

# %%
y_prediction_x=best_model.predict(np.array(X_test).reshape(-1,window_size,4))
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %%
display_metrics(model_evaluation(Y_test,y_prediction_x),"Matrix_Evalution_avg.png")
# Out:
# Metrics plot saved to Matrix_Evalution_avg.png

# %%
r2_score(Y_test[:30],y_prediction_x[:30])

# %% [markdown]
# ## ALL MODEL EVALUTION

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,median_absolute_error

# %%
from meteostat import Point, Daily
import datetime

def prepare_data(feature,scaler):    
    location = Point( 23.0215374, 72.5800568)
    start = datetime.datetime(1990, 6, 1)
    end = datetime.datetime(2024, 6, 1)
    
    # Get historical data
    data = Daily(location, start, end)
    data = data.fetch()
    
    
    temperature_avg=data[feature]
    print("TOTAL NULL VALUES IN DATASET:",temperature_avg.isnull().sum())
    temperature_avg.dropna(inplace=True)
    
    temperature_avg_seq=temperature_avg.values
    print(temperature_avg_seq,temperature_avg_seq.shape)
    
    
    
    window_size=100
    
    X=[]
    Y=[]
    for i in range(len(temperature_avg_seq)-window_size):
      X.append(temperature_avg_seq[i:i+window_size])
      Y.append(temperature_avg_seq[i+window_size])
    
    X=np.array(X)
    Y=np.array(Y)

    X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

    print("X_train Shape",X_train.shape)
    print("X_test Shape",X_test.shape)
    print("Y_train Shape",Y_train.shape)
    print("Y_test Shape",Y_test.shape)


    X_train_Scaled=scaler.transform(X_train.reshape(-1,1))
    X_test_Scaled=scaler.transform(X_test.reshape(-1,1))

    X_train=X_train_Scaled.reshape(X_train.shape[0],100)
    X_test=X_test_Scaled.reshape(X_test.shape[0],100)

    
    print("AFTER SCALED")
    print("X_train Shape",X_train.shape)
    print("X_test Shape",X_test.shape)
    print("Y_train Shape",Y_train.shape)
    print("Y_test Shape",Y_test.shape)
    




    
    return X_train,X_test,Y_train,Y_test

# %%
def model_evaluation(y_true, y_pred):
    """Compute evaluation metrics."""
    mse = mean_squared_error(y_true, y_pred)
    mae=mean_absolute_error(y_true,y_pred)
    medianae=median_absolute_error(y_true,y_pred)
    
    
    metrics = {
        "Mean Sqaured Error": mse,
        "Mean Absolute Error": mae,
        "Median Absolute Error": medianae
    }
    return metrics

# %%
def display_all_metrics(metrics_dicts, features):
   
    fig, ax = plt.subplots(figsize=(12, 6))
 
    num_groups = len(metrics_dicts)
    bar_width = 0.15
    indices = np.arange(len(metrics_dicts[0])) 
    
    
    for i, (metrics, feature) in enumerate(zip(metrics_dicts, features)):
        bar_positions = indices + i * bar_width
        ax.barh(bar_positions, list(metrics.values()), bar_width, label=feature)
 
        for j, v in enumerate(metrics.values()):
            ax.text(v + 0.01, bar_positions[j], f"{v:.2f}", va="center", fontsize=9)
    
 
    ax.set_title("Model Evaluation Metrics", fontsize=16, fontweight="bold")
    ax.set_xlabel("Scores", fontsize=12)
    ax.set_xlim(0, 4) 
    ax.set_yticks(indices + (num_groups - 1) * bar_width / 2)
    ax.set_yticklabels(metrics_dicts[0].keys(), fontsize=10)
    ax.legend(loc="best", title="Feature Sets", fontsize=10)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 1. TEMPERATURE AVERAGE

# %% [markdown]
# ## MIN MAX SCALER

# %%
from tensorflow.keras.models import load_model
best_model=load_model("/kaggle/working/temperature_best_avg_MinMax.keras")
# best_model.save("upgraded_naive_model_best_avg.h5")

# %%
MinMax_Avg=pkl.load(open("/kaggle/working/MinMax_Avg_MinMax.pkl","rb"))

# %%
X_train,X_test,Y_train,Y_test=prepare_data("tavg",MinMax_Avg)

# %%
y_prediction_x=best_model.predict(np.array(X_test).reshape(-1,window_size,1))

# %%
y_prediction_x[0],Y_test[0]

# %%
from sklearn.metrics import mean_squared_error
print("MEAN SQAURED ERROR:",mean_squared_error(Y_test,y_prediction_x))

temp_avg_minmax=model_evaluation(Y_test,y_prediction_x)

# %% [markdown]
# ## STANDARD SCALER

# %%
from tensorflow.keras.models import load_model
best_model=load_model("/kaggle/working/temperature_best_avg.keras")
# best_model.save("upgraded_naive_model_best_avg.h5")

# %%
Standard_Avg=pkl.load(open("/kaggle/working/MinMax_Avg.pkl","rb"))

# %%
X_train,X_test,Y_train,Y_test=prepare_data("tavg",Standard_Avg)

# %%
y_prediction_x=best_model.predict(np.array(X_test).reshape(-1,window_size,1))

# %%
from sklearn.metrics import mean_squared_error
print("MEAN SQAURED ERROR:",mean_squared_error(Y_test,y_prediction_x))


temp_avg_Standard=model_evaluation(Y_test,y_prediction_x)

# %% [markdown]
# # 2.TEMPERATURE MINIMUM

# %% [markdown]
# ## 1.MINMAX SCALER

# %%
from tensorflow.keras.models import load_model
best_model=load_model("/kaggle/working/temperature_best_min_MinMax.keras")
# best_model.save("upgraded_naive_model_best_avg.h5")

# %%
MinMax_Avg=pkl.load(open("/kaggle/working/MinMaxScaler_min.pkl","rb"))

# %%
X_train,X_test,Y_train,Y_test=prepare_data("tmin",MinMax_Avg)

# %%
y_prediction_x=best_model.predict(np.array(X_test).reshape(-1,window_size,1))

# %%
from sklearn.metrics import mean_squared_error
print("MEAN SQAURED ERROR:",mean_squared_error(Y_test,y_prediction_x))



temp_min_minmax=model_evaluation(Y_test,y_prediction_x)

# %% [markdown]
# ## 2. Standard Scaler

# %%
from tensorflow.keras.models import load_model
best_model=load_model("/kaggle/working/temperature_best_min_StandardScaler.keras")
# best_model.save("upgraded_naive_model_best_avg.h5")

# %%
Standard_Avg=pkl.load(open("/kaggle/working/StandardScaler_min.pkl","rb"))

# %%
X_train,X_test,Y_train,Y_test=prepare_data("tmin",Standard_Avg)

# %%
y_prediction_x=best_model.predict(np.array(X_test).reshape(-1,window_size,1))

# %%
from sklearn.metrics import mean_squared_error
print("MEAN SQAURED ERROR:",mean_squared_error(Y_test,y_prediction_x))


temp_min_Standard=model_evaluation(Y_test,y_prediction_x)

# %% [markdown]
# # 3.TEMPERATURE MAX

# %% [markdown]
# ## 1. MinMax Scaler

# %%
from tensorflow.keras.models import load_model
best_model=load_model("/kaggle/working/temperature_best_max_MinMax.keras")
# best_model.save("upgraded_naive_model_best_avg.h5")

# %%
MinMax_Max=pkl.load(open("/kaggle/working/MinMax_Max.pkl","rb"))

# %%
X_train,X_test,Y_train,Y_test=prepare_data("tmax",MinMax_Max)

# %%
y_prediction_x=best_model.predict(np.array(X_test).reshape(-1,window_size,1))

# %%
from sklearn.metrics import mean_squared_error
print("MEAN SQAURED ERROR:",mean_squared_error(Y_test,y_prediction_x))


temp_max_minmax=model_evaluation(Y_test,y_prediction_x)

# %% [markdown]
# ## 2. Standard Scaler

# %%
from tensorflow.keras.models import load_model
best_model=load_model("/kaggle/working/temperature_best_max_StandardScaler.keras")
# best_model.save("upgraded_naive_model_best_avg.h5")

# %%
Standard_Max=pkl.load(open("/kaggle/working/StandardScaler.pkl","rb"))

# %%
X_train,X_test,Y_train,Y_test=prepare_data("tmax",Standard_Max)

# %%
y_prediction_x=best_model.predict(np.array(X_test).reshape(-1,window_size,1))

# %%
from sklearn.metrics import mean_squared_error
print("MEAN SQAURED ERROR:",mean_squared_error(Y_test,y_prediction_x))


temp_max_standard=model_evaluation(Y_test,y_prediction_x)

# %% [markdown]
# ## VISUAL

# %%
metrics_dicts = [
    temp_avg_minmax, temp_avg_Standard,
    temp_min_minmax, temp_min_Standard,
    temp_max_minmax, temp_max_standard
]
features = [
    "Temperature Average MinMax", "Temperature Average Standard",
    "Temperature MiniMum MinMax", "Temperature MiniMum Standard",
    "Temperature Maximum MinMax", "Temperature Maximum Standard"
]

# Display all metrics in a single plot
display_all_metrics(metrics_dicts, features)

# %% [markdown]
#  <h1 style="text-align:center;">END</h1>

# %% [markdown]
# ---
