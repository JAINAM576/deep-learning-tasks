# %% [markdown]
# - applies filtering, image processing methods on -> https://www.kaggle.com/datasets/bemorekgg/kidney-stone-segmentation-dataset/data
# - train  SAM 2 (Segment Anything Model 2) by Meta segmentation model on this dataset -> https://www.kaggle.com/datasets/mahyeks/pothrgbd-rgb-and-depth-images-of-potholes, https://www.kaggle.com/datasets/lorenzoarcioni/road-damage-dataset-potholes-cracks-and-manholes/data
# - for classification model (ViT (Vision Transformer) ) ->
# - object  detection yolo model -> https://www.kaggle.com/datasets/banuprasadb/visdrone-dataset
